# %% [markdown]
# ### Required Imports

# %%
import sys
import os
sys.path.insert(0, 'core/')
from analysis import create_denoising_dataset
import nibabel as nib, scipy.io as sio
from utils import list_to_nib
from tkinter import Tk
from tkinter.filedialog import askdirectory

# %% [markdown]
# ### Set Path for Files

# %%
# hide the tk root window
Tk().withdraw() 

# user specify data directory
# print('Select directory containing the phantom data, log file, and acqtime file')
mainpath = askdirectory(title = 'Path to Phantom Data')

# make output directory
outpath = mainpath + '/Extracted Time Series'
os.makedirs(outpath, exist_ok = True)

# %%
# set path for input files 
epi_path = mainpath + '/epi/epi_corrected.nii' # Path of intensity nonuniformity corrected fMRI measurement in nifti format.
log_path = mainpath + 'epi/log.csv' # Path of phantom-log file obtained from your BrainDancer device.
acqtimes_path = mainpath + 'Acqtimes.csv' # Path of slice-acquistion order of your acquistion protocol in csv format.

# %%
# set path for output files
ground_truth_ts = outpath + '/groundtruth.nii' # Path for saving the ground truth.
measured_fmri_ts = outpath + '/measured.nii' # Path for saving the extracted measured fMRI time series. 
masks = outpath + '/masks.nii' # Path for saving masks of the extracted slices. 
center_rotation = outpath + '/center.mat' # Path for saving the center of rotation used for creating ground-truth. 
slices = outpath + '/slices.mat' # Path for saving a log of slices used for ground-truth and measured fMRI time series.

# %%
# %matplotlib ipympl
import nibabel as nib
import matplotlib.pyplot as plt
from matplotlib.widgets import RangeSlider

# %%
def display_all_slices(data,volume_number):
    data_read = data
    count = 1
    dim = data_read.header['dim'][3]
    fig = plt.figure(figsize=(15,dim+10))
    lowThres = 0
    highThres = dim
    
    for i in range(dim):
        fig.subplots_adjust(hspace=0, wspace=0.0005)      
        ax = fig.add_subplot(int(dim/4 +1) ,4, count)
        im= plt.imshow(data_read.get_data()[:,:,i,volume_number])
        ax.set_title('Slice '+str(i),fontsize=18)
        ax.set_axis_off()
        count+=1
    slider_ax = plt.axes([0.20, 1/(dim/4+1), 0.60, 0.03])
    slider = RangeSlider(slider_ax, "Threshold", 0, dim)
    
    def update(val):
        # Update the threshold for color map
        lowThres = val[0]
        highThres = val[1]

        # Redraw the figure to ensure it updates
        fig.canvas.draw_idle()


    slider.on_changed(update)
    plt.show()

# %%
data_read = nib.load(epi_path)
display_all_slices(data_read,0)
# Out:
# /var/folders/qh/8lv4v0ws1g17mk7kcgk2bf4w0000gn/T/ipykernel_7370/3246791686.py:12: DeprecationWarning: get_data() is deprecated in favor of get_fdata(), which has a more predictable return type. To obtain get_data() behavior going forward, use numpy.asanyarray(img.dataobj).
#
# * deprecated from version: 3.0
# * Will raise <class 'nibabel.deprecator.ExpiredDeprecationError'> as of version: 5.0
#   im= plt.imshow(data_read.get_data()[:,:,i,volume_number])
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
dim = data_read.header['dim'][3].astype('int')

# %%
from ipywidgets import interactive
dim = data_read.header['dim'][3]
from IPython.display import display

def myfunction(x):
    return x

widget = interactive(myfunction, x = dim/4)
display(widget)
# Out:
# interactive(children=(FloatSlider(value=7.0, description='x', max=21.0, min=-7.0), Output()), _dom_classes=('w…

# %%
data_read = nib.load(epi_path)
volume_number = 0
count = 1
dim = data_read.header['dim'][3]
fig = plt.figure(figsize=(15,dim+10))

for i in range(dim):
    fig.subplots_adjust(hspace=0, wspace=0.0005)      
    ax = fig.add_subplot(int(dim/4 +1) ,4, count)
    im= plt.imshow(data_read.get_data()[:,:,i,volume_number])
    ax.set_title('Slice '+str(i),fontsize=18)
    ax.set_axis_off()
    count+=1
# Out:
# /var/folders/qh/8lv4v0ws1g17mk7kcgk2bf4w0000gn/T/ipykernel_4479/3303000520.py:10: DeprecationWarning: get_data() is deprecated in favor of get_fdata(), which has a more predictable return type. To obtain get_data() behavior going forward, use numpy.asanyarray(img.dataobj).
#
# * deprecated from version: 3.0
# * Will raise <class 'nibabel.deprecator.ExpiredDeprecationError'> as of version: 5.0
#   im= plt.imshow(data_read.get_data()[:,:,i,volume_number])

# %% [markdown]
# ### Run the Extraction

# %%
ground_truth, measured_fmri, imask, center, all_slices = create_denoising_dataset(epi_path,log_path,acqtimes_path,rot_dir=-1)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Input In [22], in <cell line: 1>()
# ----> 1 ground_truth, measured_fmri, imask, center, all_slices = create_denoising_dataset(epi_path,log_path,acqtimes_path,rot_dir=-1)
#
# File ~/Desktop/Git/fMRI_BrainDancer/core/analysis.py:36, in create_denoising_dataset(epi_path, log_path, acqtimes_path, rot_dir)
#      32 def create_denoising_dataset(epi_path,log_path,acqtimes_path,rot_dir=-1):
#      33     data_read = nib.load(epi_path)
# ---> 36     display_all_slices(data_read,0)
#      37     plt.show()
#      39     start = int(input('Enter the first good slice: '))
#
# File ~/Desktop/Git/fMRI_BrainDancer/core/display.py:30, in display_all_slices(data, volume_number)
#      28 for i in range(data_read.header['dim'][3]):
#      29     fig.subplots_adjust(hspace=0, wspace=0.0005)
# ---> 30     ax = fig.add_subplot(data_read.header['dim'][3]/4 +1 ,4, count)
#      31     im= plt.imshow(data_read.get_data()[:,:,i,volume_number])
#      32     ax.set_title('Slice '+str(i),fontsize=18)
#
# File ~/miniforge3/lib/python3.9/site-packages/matplotlib/figure.py:772, in FigureBase.add_subplot(self, *args, **kwargs)
#     769         args = tuple(map(int, str(args[0])))
#     770     projection_class, pkw = self._process_projection_requirements(
#     771         *args, **kwargs)
# --> 772     ax = subplot_class_factory(projection_class)(self, *args, **pkw)
#     773     key = (projection_class, pkw)
#     774 return self._add_axes_internal(ax, key)
#
# File ~/miniforge3/lib/python3.9/site-packages/matplotlib/axes/_subplots.py:36, in SubplotBase.__init__(self, fig, *args, **kwargs)
#      34 self._axes_class.__init__(self, fig, [0, 0, 1, 1], **kwargs)
#      35 # This will also update the axes position.
# ---> 36 self.set_subplotspec(SubplotSpec._from_subplot_args(fig, args))
#
# File ~/miniforge3/lib/python3.9/site-packages/matplotlib/gridspec.py:597, in SubplotSpec._from_subplot_args(figure, args)
#     593 else:
#     594     raise TypeError(f"subplot() takes 1 or 3 positional arguments but "
#     595                     f"{len(args)} were given")
# --> 597 gs = GridSpec._check_gridspec_exists(figure, rows, cols)
#     598 if gs is None:
#     599     gs = GridSpec(rows, cols, figure=figure)
#
# File ~/miniforge3/lib/python3.9/site-packages/matplotlib/gridspec.py:225, in GridSpecBase._check_gridspec_exists(figure, nrows, ncols)
#     223             return gs
#     224 # else gridspec not found:
# --> 225 return GridSpec(nrows, ncols, figure=figure)
#
# File ~/miniforge3/lib/python3.9/site-packages/matplotlib/gridspec.py:385, in GridSpec.__init__(self, nrows, ncols, figure, left, bottom, right, top, wspace, hspace, width_ratios, height_ratios)
#     382 self.hspace = hspace
#     383 self.figure = figure
# --> 385 super().__init__(nrows, ncols,
#     386                  width_ratios=width_ratios,
#     387                  height_ratios=height_ratios)
#
# File ~/miniforge3/lib/python3.9/site-packages/matplotlib/gridspec.py:49, in GridSpecBase.__init__(self, nrows, ncols, height_ratios, width_ratios)
#      34 """
#      35 Parameters
#      36 ----------
#    (...)
#      46     If not given, all rows will have the same height.
#      47 """
#      48 if not isinstance(nrows, Integral) or nrows <= 0:
# ---> 49     raise ValueError(
#      50         f"Number of rows must be a positive integer, not {nrows!r}")
#      51 if not isinstance(ncols, Integral) or ncols <= 0:
#      52     raise ValueError(
#      53         f"Number of columns must be a positive integer, not {ncols!r}")
#
# ValueError: Number of rows must be a positive integer, not 8.0

# %% [markdown]
# ### Save the Results

# %%
nib.save(ground_truth,ground_truth_ts)
nib.save(measured_fmri,measured_fmri_ts)
nib.save(list_to_nib(imask,ground_truth.affine),masks)
sio.savemat(center_rotation,{'center':center}) 
sio.savemat(center_rotation,{'slices':all_slices})
